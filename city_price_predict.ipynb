# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('city_data.csv')

# %%
le = LabelEncoder()
df["City_encoded"] = le.fit_transform(df["City"])

# %%
df
# Out:
#            City  Tier  Year  Cost_of_Living_Index  \
# 0        Mumbai     1  2015                   100
# 1        Mumbai     1  2020                   115
# 2        Mumbai     1  2025                   135
# 3     Delhi NCR     1  2015                    85
# 4     Delhi NCR     1  2020                    98
# 5     Delhi NCR     1  2025                   110
# 6     Bengaluru     1  2015                    75
# 7     Bengaluru     1  2020                    90
# 8     Bengaluru     1  2025                   105
# 9          Pune     1  2015                    65
# 10         Pune     1  2020                    78
# 11         Pune     1  2025                    90
# 12    Ahmedabad     1  2015                    55
# 13    Ahmedabad     1  2020                    65
# 14    Ahmedabad     1  2025                    75
# 15       Jaipur     2  2015                    45
# 16       Jaipur     2  2020                    55
# 17       Jaipur     2  2025                    65
# 18      Lucknow     2  2015                    40
# 19      Lucknow     2  2020                    50
# 20      Lucknow     2  2025                    60
# 21   Coimbatore     2  2015                    40
# 22   Coimbatore     2  2020                    48
# 23   Coimbatore     2  2025                    58
# 24     Vadodara     3  2015                    35
# 25     Vadodara     3  2020                    40
# 26     Vadodara     3  2025                    50
# 27  Bhubaneswar     3  2015                    38
# 28  Bhubaneswar     3  2020                    45
# 29  Bhubaneswar     3  2025                    55
#
#     Average_Annual_Salary_INR_Lakhs Dominating_Sector  \
# 0                               8.0           Finance
# 1                               9.5           Finance
# 2                              12.5           Finance
# 3                               7.5        Government
# 4                               9.0          Services
# 5                              11.0        E-commerce
# 6                               8.5           IT/ITES
# 7                              11.0                IT
# 8                              14.0              Tech
# 9                               7.0        Automotive
# 10                              9.0           IT/ITES
# 11                             11.5                IT
# 12                              6.0           Textile
# 13                              7.5             Trade
# 14                              9.0             Trade
# 15                              4.5           Tourism
# 16                              5.5           Tourism
# 17                              7.0       Real Estate
# 18                              4.0        Government
# 19                              5.0         Education
# 20                              6.5        E-commerce
# 21                              4.5           Textile
# 22                              5.5       Engineering
# 23                              7.0           IT/ITES
# 24                              4.0     Petrochemical
# 25                              5.0     Petrochemical
# 26                              6.0     Manufacturing
# 27                              3.5        Government
# 28                              4.5         Education
# 29                              6.0         Education
#
#     Avg_House_Price_per_Sq_Ft_INR  City_encoded
# 0                           18000             7
# 1                           21000             7
# 2                           25000             7
# 3                           12000             4
# 4                           14500             4
# 5                           16500             4
# 6                            8000             1
# 7                           11000             1
# 8                           14000             1
# 9                            6000             8
# 10                           8500             8
# 11                          11500             8
# 12                           3500             0
# 13                           5000             0
# 14                           6500             0
# 15                           2500             5
# 16                           3500             5
# 17                           4500             5
# 18                           2000             6
# 19                           3000             6
# 20                           4000             6
# 21                           3000             3
# 22                           4000             3
# 23                           5500             3
# 24                           1800             9
# 25                           2500             9
# 26                           3500             9
# 27                           1500             2
# 28                           2500             2
# 29                           4000             2

# %%
x = df[["City_encoded","Tier", "Year", "Cost_of_Living_Index", "Average_Annual_Salary_INR_Lakhs"]]
y = df["Avg_House_Price_per_Sq_Ft_INR"]

# %%
x
# Out:
#     City_encoded  Tier  Year  Cost_of_Living_Index  \
# 0              7     1  2015                   100
# 1              7     1  2020                   115
# 2              7     1  2025                   135
# 3              4     1  2015                    85
# 4              4     1  2020                    98
# 5              4     1  2025                   110
# 6              1     1  2015                    75
# 7              1     1  2020                    90
# 8              1     1  2025                   105
# 9              8     1  2015                    65
# 10             8     1  2020                    78
# 11             8     1  2025                    90
# 12             0     1  2015                    55
# 13             0     1  2020                    65
# 14             0     1  2025                    75
# 15             5     2  2015                    45
# 16             5     2  2020                    55
# 17             5     2  2025                    65
# 18             6     2  2015                    40
# 19             6     2  2020                    50
# 20             6     2  2025                    60
# 21             3     2  2015                    40
# 22             3     2  2020                    48
# 23             3     2  2025                    58
# 24             9     3  2015                    35
# 25             9     3  2020                    40
# 26             9     3  2025                    50
# 27             2     3  2015                    38
# 28             2     3  2020                    45
# 29             2     3  2025                    55
#
#     Average_Annual_Salary_INR_Lakhs
# 0                               8.0
# 1                               9.5
# 2                              12.5
# 3                               7.5
# 4                               9.0
# 5                              11.0
# 6                               8.5
# 7                              11.0
# 8                              14.0
# 9                               7.0
# 10                              9.0
# 11                             11.5
# 12                              6.0
# 13                              7.5
# 14                              9.0
# 15                              4.5
# 16                              5.5
# 17                              7.0
# 18                              4.0
# 19                              5.0
# 20                              6.5
# 21                              4.5
# 22                              5.5
# 23                              7.0
# 24                              4.0
# 25                              5.0
# 26                              6.0
# 27                              3.5
# 28                              4.5
# 29                              6.0

# %%
y
# Out:
# 0     18000
# 1     21000
# 2     25000
# 3     12000
# 4     14500
# 5     16500
# 6      8000
# 7     11000
# 8     14000
# 9      6000
# 10     8500
# 11    11500
# 12     3500
# 13     5000
# 14     6500
# 15     2500
# 16     3500
# 17     4500
# 18     2000
# 19     3000
# 20     4000
# 21     3000
# 22     4000
# 23     5500
# 24     1800
# 25     2500
# 26     3500
# 27     1500
# 28     2500
# 29     4000
# Name: Avg_House_Price_per_Sq_Ft_INR, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 6458.75861973,  3657.78143355,  4838.44628765,  4019.61608001,
#        12531.80995829,  3480.94339881])

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8897660655670232

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 837.5781634022327
