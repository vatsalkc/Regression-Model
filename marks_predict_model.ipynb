# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('student_performance.csv')

# %%
df
# Out:
#     Hours_Studied  Lectures_Attended  Sleep_Hours  Exam_Score
# 0              11                 16            6       33.46
# 1              24                 30            7       59.22
# 2              19                 18            8       46.74
# 3              15                 48            7       63.39
# 4              12                 27            8       43.73
# 5              11                 13            6       28.19
# 6              23                 34            7       55.23
# 7              15                 23            8       47.00
# 8              15                 18            5       35.56
# 9               8                 35            6       42.22
# 10             12                 11            8       35.20
# 11              7                 29            5       34.00
# 12              6                 37            8       47.84
# 13             16                 16            5       36.24
# 14             10                 17            6       29.16
# 15              6                 44            7       49.31
# 16              5                 23            5       32.18
# 17             16                 26            8       49.49
# 18             16                 45            6       62.49
# 19             21                 49            5       66.10
# 20             14                 13            8       44.18
# 21             20                 11            8       37.95
# 22             19                 15            8       41.25
# 23             19                 13            5       36.10
# 24             23                 38            5       55.45
# 25             16                 27            5       46.36
# 26             24                 35            7       63.01
# 27              7                 43            5       46.80
# 28              9                 19            5       29.41
# 29             23                 45            5       60.51

# %%
x = df.iloc[:,0:3].to_numpy()

# %%
y = df['Exam_Score'].to_numpy()

# %%
y
# Out:
# array([33.46, 59.22, 46.74, 63.39, 43.73, 28.19, 55.23, 47.  , 35.56,
#        42.22, 35.2 , 34.  , 47.84, 36.24, 29.16, 49.31, 32.18, 49.49,
#        62.49, 66.1 , 44.18, 37.95, 41.25, 36.1 , 55.45, 46.36, 63.01,
#        46.8 , 29.41, 60.51])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()

# %%
x_train.shape
# Out:
# (24, 3)

# %%
y_train.shape
# Out:
# (24,)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([63.73173527, 35.52455399, 43.86834299, 32.15136487, 32.35955005,
#        29.65103076])

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.9549878673059492

# %%
mae
# Out:
# 1.9210513879789552

# %%
mse
# Out:
# 4.942134741591437

# %%
rmse
# Out:
# np.float64(2.2230912580439512)
